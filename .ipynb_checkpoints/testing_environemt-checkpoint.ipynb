# %% [markdown]
# This is just a test to see if all environment settings are working

# %%
import osmnx as ox
import geopandas as gpd
from shapely.geometry import Point, LineString, MultiPoint

# %%
from shapely.ops import triangulate, poligonize

# %%
import momepy as mm

# %%
point = 40.41932, -3.69307 #cibeles, Madrid
dist = 500
G = ox.graph_from_point(point, dist=dist, network_type='drive', simplify = True)
nodes, edges = ox.graph_to_gdfs(G)

# %%
edges.plot()
# Out:
# <AxesSubplot:>

# %%
#use only the geometry and a basic id as a starting point to homogenize 
edges_minimal = gpd.GeoDataFrame(edges.reset_index()['geometry'])
edges_minimal = edges_minimal.to_crs(2062)

#storing the first and last points of each edge
edges_minimal['first'] = edges_minimal.geometry.apply(lambda x : Point(x.coords[0]) )
edges_minimal['last'] = edges_minimal.geometry.apply(lambda x : Point(x.coords[-1]) )
edges_minimal.tail()
# Out:
#                                               geometry  \
# 778  LINESTRING (599842.371 646075.760, 599852.265 ...
# 779  LINESTRING (599830.247 646074.718, 599842.371 ...
# 780  LINESTRING (599777.582 646632.544, 599761.010 ...
# 781  LINESTRING (599801.143 646732.631, 599814.072 ...
# 782  LINESTRING (599278.501 646095.902, 599280.841 ...
#
#                              first                           last
# 778  POINT (599842.371 646075.760)  POINT (599852.265 646077.501)
# 779  POINT (599830.247 646074.718)  POINT (599842.371 646075.760)
# 780  POINT (599777.582 646632.544)  POINT (599761.010 646640.963)
# 781  POINT (599801.143 646732.631)  POINT (599814.072 646762.167)
# 782  POINT (599278.501 646095.902)  POINT (599280.841 646098.308)

# %%
# polygonize network
# here we need to make sure the outter convex/concave hull is also considered.
polys = list(polygonize(edges_minimal.geometry.to_list()))
crs = edges_minimal.crs
gdf = gpd.GeoDataFrame(geometry=polys, crs=crs)
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
edges.to_file('edges.gpkg', driver='GPKG')
# Out:
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/geopandas/io/file.py:389: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(gdal_version) >= LooseVersion("3.0.0") and crs:

# %%
# filter potentially incorrect polygons - TODO
# Can we include here some ML classigfication for this identification?
max_size = 10000
circom_max = 0.2
# calculate parameters
gdf["area"] = gdf.geometry.area
gdf["circom"] = mm.CircularCompactness(gdf, "area").series
# select valid and invalid network-net_blocks
possible = gdf.loc[gdf["area"] < max_size]
invalid = possible.loc[ (possible["circom"] < circom_max) ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [87], in <cell line: 7>()
#       5 # calculate parameters
#       6 gdf["area"] = gdf.geometry.area
# ----> 7 gdf["circom"] = mm.CircularCompactness(gdf, "area").series
#       8 # select valid and invalid network-net_blocks
#       9 possible = gdf.loc[gdf["area"] < max_size]
#
# AttributeError: module 'momepy' has no attribute 'CircularCompactness'

# %%
# intersecting the buildings of the area would leave out the INVALID polygons too
# too expensive, but a temporary workaround
buildings = ox.geometries_from_point(point, tags = {'building': True}, dist= dist)
buildings = buildings.to_crs(gdf.crs)
buildings.plot()
# Out:
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# <AxesSubplot:>

# %%
valid = gpd.sjoin(gdf, buildings, how= 'inner')
valid = valid[['geometry','area']]
valid.index.name = 'index'

valid.plot()
# Out:
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# <AxesSubplot:>

# %%
#exclude also those poligons with low density/footprint
b_footprint =  valid.reset_index().groupby('index')['area'].sum()

# %%
v_series = valid.drop_duplicates(subset = 'geometry')['geometry']
valid  = gpd.GeoDataFrame(b_footprint, geometry = v_series)
valid.tail()
# Out:
#                 area                                           geometry
# index
# 70       2864.184728  POLYGON ((599805.730 646096.313, 599805.349 64...
# 72      48848.035137  POLYGON ((599739.165 646197.656, 599649.004 64...
# 73      88999.601570  POLYGON ((599863.154 646288.014, 599737.837 64...
# 74      53037.415281  POLYGON ((599737.837 646285.166, 599647.194 64...
# 75     153710.692269  POLYGON ((599736.747 646381.040, 599735.224 64...

# %%
valid.rename(columns = {'area': 'buildings_ftp'}, inplace=True)
valid['footprint_ratio'] = valid.geometry.area/valid['buildings_ftp']

# %%
valid.head()
# Out:
#        buildings_ftp                                           geometry  \
# index
# 2       82092.821139  POLYGON ((599863.154 646288.014, 599859.465 64...
# 3       24212.722579  POLYGON ((599282.324 646451.809, 599355.859 64...
# 5        5888.784649  POLYGON ((599282.324 646451.809, 599284.188 64...
# 7       99425.483405  POLYGON ((599876.705 646512.811, 599876.679 64...
# 10     295385.231307  POLYGON ((599186.017 646419.510, 599232.517 64...
#
#        footprint_ratio
# index
# 2             0.125000
# 3             1.000000
# 5             1.000000
# 7             0.142857
# 10            0.062500

# %%
valid.plot('footprint_ratio', figsize = (10,10))
# Out:
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
f, ax = plt.subplots()

valid.plot(ax=ax,column= 'footprint_ratio')
buildings.plot(ax=ax, color='#fff7ff')

plt.show()
# Out:
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %%
# quick attempots locally in QGIS
edges.to_crs(buildings.crs).to_file('edges.gpkg', driver='GPKG')
buildings.reset_index().loc[:,'element_type':'geometry':1].to_file('buildings.gpkg', driver='GPKG')
# Out:
# /Users/gregoriomaya/mambaforge/envs/test/lib/python3.10/site-packages/geopandas/io/file.py:389: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(gdal_version) >= LooseVersion("3.0.0") and crs:
